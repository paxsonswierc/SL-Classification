# %%
# arrays
import numpy as np

# fits
from astropy.io import fits
from astropy.utils.data import download_file
from astropy.visualization import simple_norm

# plotting
# %matplotlib inline
from matplotlib import pyplot as plt
import random

# keras
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# sklearn (for machine learning)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

#from astropy.visualization import make_lupton_rgb

# %%
config1 = np.load('D:/SL CNN/CONFIGURATION_1_images2.npy')
config2 = np.load('D:/SL CNN/CONFIGURATION_2_images2.npy')

# %%
print(np.shape(config1))
print(np.shape(config2))
# Out:
# (1499, 3, 100, 100)
# (1499, 3, 100, 100)

# %%
data = np.concatenate((config1, config2), axis=0)
print(np.shape(data))
# Out:
# (2998, 3, 100, 100)

# %%
label1 = np.ones(len(config1[0:]))
label2 = np.zeros(len(config2[0:]))
label = np.concatenate((label1, label2))
print(np.shape(label))
# Out:
# (2998,)

# %%
#get random indices
x = np.empty(1)
i = 1

while i < 16:
    example_num = int(random.randrange(0, len(data[0:])))
    if example_num != x[i-1]:
        x = np.append(x, [example_num])
        i += 1

# %%
#plot the examples
fig1=plt.figure(figsize=(8,8))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.axis("off")
    
    example_indices = int(x[i])
    
    example_image = np.squeeze(data[example_indices:(example_indices + 1), 0:1]) #change band by switching 0:1 to 1:2 or 2:3
    
    plt.imshow(example_image, aspect='auto', cmap='viridis')
    if label[example_indices] == 1:
        plt.title('Einstein Ring')
    else:
        plt.title('Single Galaxy')

# %%
y = label.astype('float32')
X = data.astype('float32')

# %%
X_train, X_split, y_train, y_split = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

X_valid, X_test, y_valid, y_test = train_test_split(X_split, y_split, test_size=0.666, random_state=42, shuffle=True)

# %%
imsize = np.shape(X_train)[2]

X_train = X_train.reshape(-1, imsize, imsize, 3)
X_valid = X_valid.reshape(-1, imsize, imsize, 3)
X_test = X_test.reshape(-1, imsize, imsize, 3)

print(np.shape(X_train))
# Out:
# (2098, 100, 100, 3)

# %%
imsize = np.shape(X_train)[2]

data_shape = np.shape(X)
input_shape = (imsize, imsize, 3)

x_in = Input(shape=input_shape)
a0 = Convolution2D(32, (3, 3), activation='relu')(x_in)
b0 = MaxPooling2D()(a0)

a1 = Convolution2D(32, (3, 3), activation='relu')(b0)
b1 = MaxPooling2D()(a1)

a2 = Convolution2D(32, (3, 3), activation='relu')(b1)
b2 = MaxPooling2D()(a2)

a3 = Flatten()(b2)

a4 = Dense(64, activation='relu')(a3)
b4 = Dense(128, activation='relu')(a4)

y_out = Dense(1, activation='sigmoid')(b4)

model = Model(inputs=x_in, outputs=y_out)

# %%
#from keras.optimizers import SGD
opt = 'adam'
metrics = ['accuracy']
loss = 'binary_crossentropy'
model.compile(loss=loss, optimizer=opt, metrics=metrics)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 232,705
# Trainable params: 232,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
nb_epoch = 20
batch_size = 128
shuffle = True

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=nb_epoch,
                    validation_data=(X_valid, y_valid),                
                    shuffle=shuffle,
                    verbose=True)
# Out:
# Epoch 1/20
# 17/17 [==============================] - 5s 245ms/step - loss: 0.6548 - accuracy: 0.7788 - val_loss: 0.2409 - val_accuracy: 0.9833
# Epoch 2/20
# 17/17 [==============================] - 4s 235ms/step - loss: 0.1715 - accuracy: 0.9776 - val_loss: 0.0716 - val_accuracy: 0.9967
# Epoch 3/20
# 17/17 [==============================] - 4s 235ms/step - loss: 0.0597 - accuracy: 0.9938 - val_loss: 0.0262 - val_accuracy: 0.9967
# Epoch 4/20
# 17/17 [==============================] - 4s 239ms/step - loss: 0.0188 - accuracy: 0.9971 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 5/20
# 17/17 [==============================] - 4s 254ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.0073 - val_accuracy: 0.9967
# Epoch 6/20
# 17/17 [==============================] - 4s 261ms/step - loss: 0.0078 - accuracy: 0.9986 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 7/20
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 8/20
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 9/20
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 10/20
# 17/17 [==============================] - 4s 262ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 11/20
# 17/17 [==============================] - 4s 259ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 2.5802e-04 - val_accuracy: 1.0000
# Epoch 12/20
# 17/17 [==============================] - 4s 260ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.3625e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 17/17 [==============================] - 4s 259ms/step - loss: 4.0094e-04 - accuracy: 1.0000 - val_loss: 1.5328e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 17/17 [==============================] - 4s 260ms/step - loss: 1.7433e-04 - accuracy: 1.0000 - val_loss: 1.3971e-04 - val_accuracy: 1.0000
# Epoch 15/20
# 17/17 [==============================] - 4s 259ms/step - loss: 1.0982e-04 - accuracy: 1.0000 - val_loss: 2.5535e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 17/17 [==============================] - 4s 264ms/step - loss: 2.3444e-05 - accuracy: 1.0000 - val_loss: 1.2459e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 17/17 [==============================] - 4s 263ms/step - loss: 7.8694e-06 - accuracy: 1.0000 - val_loss: 2.9615e-06 - val_accuracy: 1.0000
# Epoch 18/20
# 17/17 [==============================] - 5s 270ms/step - loss: 5.5495e-06 - accuracy: 1.0000 - val_loss: 4.0749e-06 - val_accuracy: 1.0000
# Epoch 19/20
# 17/17 [==============================] - 4s 260ms/step - loss: 3.5213e-06 - accuracy: 1.0000 - val_loss: 2.0490e-06 - val_accuracy: 1.0000
# Epoch 20/20
# 17/17 [==============================] - 4s 258ms/step - loss: 2.5370e-06 - accuracy: 1.0000 - val_loss: 1.5314e-06 - val_accuracy: 1.0000

# %%
# plot

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = list(range(len(loss)))
figsize=(6,4)
fig, axis1 = plt.subplots(figsize=figsize)
plot1_lacc = axis1.plot(epochs, acc, 'navy', label='accuracy')
plot1_val_lacc = axis1.plot(epochs, val_acc, 'deepskyblue', label="validation accuracy")

plot1_loss = axis1.plot(epochs, loss, 'red', label='loss')
plot1_val_loss = axis1.plot(epochs, val_loss, 'lightsalmon', label="validation loss")


plots = plot1_loss + plot1_val_loss
labs = [l.get_label() for l in plots]
axis1.set_xlabel('Epoch')
axis1.set_ylabel('Loss/Accuracy')
plt.title("Loss/Accuracy History")
plt.tight_layout()
axis1.legend(loc='lower right')

# %%
score = model.evaluate(X_test, y_test, verbose=True)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 0.9983
# accuracy: 99.83%

# %%
# predict
prob = model.predict(X_test)
pred =  (prob > 0.5).astype('int32') 

fpr, tpr, thresholds = roc_curve(y_test, prob, pos_label=1)
auc = roc_auc_score(y_test, prob)


figsize=(5,5)
fig, axis1 = plt.subplots(figsize=figsize)
x_onetoone = y_onetoone = [0, 1]
plt.plot(fpr, tpr, 'r-')
plt.plot(x_onetoone, y_onetoone, 'k--',  label="1-1")
plt.legend(loc=0)
plt.title("Receiver Operator Characteristic (ROC)")
plt.xlabel("False Positive (1 - Specificity)")
plt.ylabel("True Positive (Selectivity)")
plt.text(0.5, 0.2, "AUC ="+"{0:.2f}".format(auc), fontsize = 22, 
         bbox = dict(facecolor = 'red', alpha = 0.5))
plt.tight_layout()
# Out:
# 19/19 [==============================] - 0s 15ms/step

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, pred)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.998333
# Precision: 1.000000
# Recall: 0.996732
# F1 score: 0.998363

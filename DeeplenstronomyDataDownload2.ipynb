# %%
# !pip install deeplenstronomy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deeplenstronomy in /usr/local/lib/python3.7/dist-packages (0.0.2.3)
# Requirement already satisfied: wheel>=0.22 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (0.37.1)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (3.1.0)
# Requirement already satisfied: future>=0.18.2 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (0.18.2)
# Requirement already satisfied: astropy>=4.0.1.post1 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (4.3.1)
# Requirement already satisfied: mpmath>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (1.2.1)
# Requirement already satisfied: pandas>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (1.3.5)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (1.7.3)
# Requirement already satisfied: lenstronomy>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (1.10.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (6.0)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (3.5.2)
# Requirement already satisfied: numpy>=1.19.1 in /usr/local/lib/python3.7/dist-packages (from deeplenstronomy) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0.1.post1->deeplenstronomy) (4.11.4)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0.1.post1->deeplenstronomy) (2.0.0.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.10.0->deeplenstronomy) (1.5.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (0.18.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (1.0.2)
# Requirement already satisfied: configparser in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (5.2.0)
# Requirement already satisfied: numba>=0.43.1 in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (0.51.2)
# Requirement already satisfied: corner>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (2.2.1)
# Requirement already satisfied: pyxdg in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (0.28)
# Requirement already satisfied: schwimmbad in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (0.3.2)
# Requirement already satisfied: multiprocess>=0.70.8 in /usr/local/lib/python3.7/dist-packages (from lenstronomy>=1.6.0->deeplenstronomy) (0.70.13)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.2->deeplenstronomy) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.2->deeplenstronomy) (4.1.1)
# Requirement already satisfied: dill>=0.3.5.1 in /usr/local/lib/python3.7/dist-packages (from multiprocess>=0.70.8->lenstronomy>=1.6.0->deeplenstronomy) (0.3.5.1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.1->lenstronomy>=1.6.0->deeplenstronomy) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.1->lenstronomy>=1.6.0->deeplenstronomy) (57.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.2->deeplenstronomy) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->deeplenstronomy) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0.1.post1->deeplenstronomy) (3.8.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->lenstronomy>=1.6.0->deeplenstronomy) (2.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->lenstronomy>=1.6.0->deeplenstronomy) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->lenstronomy>=1.6.0->deeplenstronomy) (1.3.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->lenstronomy>=1.6.0->deeplenstronomy) (2.6.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lenstronomy>=1.6.0->deeplenstronomy) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lenstronomy>=1.6.0->deeplenstronomy) (3.1.0)

# %%
import deeplenstronomy.deeplenstronomy as dl
from deeplenstronomy.visualize import view_image, view_image_rgb
import matplotlib.pyplot as plt

# %%
config_file_name = 'EinsteinRingWithDESBackground.yml'
dataset = dl.make_dataset(config_file_name, save_to_disk=True)

# %%
for i in range(20):
  view_image(dataset.CONFIGURATION_1_images[i])

# %%
for i in range(20):
  view_image(dataset.CONFIGURATION_2_images[i])

# %%
# !pip install deeplenstronomy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 58 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 829 kB 31.1 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.9 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 73.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.9 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 8.9 MB/s
# ...
#      |████████████████████████████████| 49 kB 7.0 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 930 kB 57.7 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=619eabd61a3004ad8664f3395fbd12b1209999f3a0eb88628b4d44a570cf3cdc
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# ...

# %%
import deeplenstronomy.deeplenstronomy as dl
from deeplenstronomy.visualize import view_image, view_image_rgb
import matplotlib.pyplot as plt

# %%
config_file_name = 'EinsteinRing3.yml'
dataset = dl.make_dataset(config_file_name)

# %%
for i in range(3):
  view_image(dataset.CONFIGURATION_1_images[i])

# %%
for i in range(3):
  view_image(dataset.CONFIGURATION_2_images[i])

# %%
saved_dataset = dl.make_dataset(config_file_name, save_to_disk=True)

# %%
import numpy as np
images = np.load('MySimulationResults/CONFIGURATION_1_images.npy')
print(np.shape(images))
images1 = np.load('MySimulationResults/CONFIGURATION_2_images.npy')
print(np.shape(images1))
# Out:
# (1499, 3, 100, 100)
# (1499, 3, 100, 100)

# %%
# arrays
import numpy as np

# fits
from astropy.io import fits
from astropy.utils.data import download_file
from astropy.visualization import simple_norm

# plotting
# %matplotlib inline
from matplotlib import pyplot as plt
import random

# keras
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# sklearn (for machine learning)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

#from astropy.visualization import make_lupton_rgb

# %%
config1 = np.load('D:/SL CNN/CONFIGURATION_1_images3.npy')
config2 = np.load('D:/SL CNN/CONFIGURATION_2_images3.npy')

# %%
print(np.shape(config1))
print(np.shape(config2))
# Out:
# (1115, 3, 100, 100)
# (1115, 3, 100, 100)

# %%
data = np.concatenate((config1, config2), axis=0)
print(np.shape(data))
# Out:
# (2230, 3, 100, 100)

# %%
label1 = np.ones(len(config1[0:]))
label2 = np.zeros(len(config2[0:]))
label = np.concatenate((label1, label2))
print(np.shape(label))
# Out:
# (2230,)

# %%
#get random indices
x = np.empty(1)
i = 1

while i < 16:
    example_num = int(random.randrange(0, len(data[0:])))
    if example_num != x[i-1]:
        x = np.append(x, [example_num])
        i += 1

# %%
#plot the examples
fig1=plt.figure(figsize=(8,8))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.axis("off")
    
    example_indices = int(x[i])
    
    example_image = np.squeeze(data[example_indices:(example_indices + 1), 0:1]) #change band by switching 0:1 to 1:2 or 2:3
    
    plt.imshow(example_image, aspect='auto', cmap='viridis')
    if label[example_indices] == 1:
        plt.title('True')
    else:
        plt.title('False')

# %%
y = label.astype('float32')
X = data.astype('float32')

# %%
X_train, X_split, y_train, y_split = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

X_valid, X_test, y_valid, y_test = train_test_split(X_split, y_split, test_size=0.666, random_state=42, shuffle=True)

# %%
imsize = np.shape(X_train)[2]

X_train = X_train.reshape(-1, imsize, imsize, 3)
X_valid = X_valid.reshape(-1, imsize, imsize, 3)
X_test = X_test.reshape(-1, imsize, imsize, 3)

print(np.shape(X_train))
# Out:
# (1561, 100, 100, 3)

# %%
imsize = np.shape(X_train)[2]

data_shape = np.shape(X)
input_shape = (imsize, imsize, 3)

x_in = Input(shape=input_shape)
a0 = Convolution2D(32, (3, 3), activation='relu')(x_in)
b0 = MaxPooling2D()(a0)

a1 = Convolution2D(32, (3, 3), activation='relu')(b0)
b1 = MaxPooling2D()(a1)

a2 = Convolution2D(32, (3, 3), activation='relu')(b1)
b2 = MaxPooling2D()(a2)

a3 = Flatten()(b2)

a4 = Dense(64, activation='relu')(a3)
b4 = Dense(128, activation='relu')(a4)

y_out = Dense(1, activation='sigmoid')(b4)

model = Model(inputs=x_in, outputs=y_out)

# %%
#from keras.optimizers import SGD
opt = 'adam'
metrics = ['accuracy']
loss = 'binary_crossentropy'
model.compile(loss=loss, optimizer=opt, metrics=metrics)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 232,705
# Trainable params: 232,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
nb_epoch = 50
batch_size = 128
shuffle = True

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=nb_epoch,
                    validation_data=(X_valid, y_valid),                
                    shuffle=shuffle,
                    verbose=True)
# Out:
# Epoch 1/50
# 13/13 [==============================] - 4s 277ms/step - loss: 4.5136 - accuracy: 0.6701 - val_loss: 0.9090 - val_accuracy: 0.6816
# Epoch 2/50
# 13/13 [==============================] - 3s 257ms/step - loss: 1.4155 - accuracy: 0.8482 - val_loss: 0.3654 - val_accuracy: 0.9283
# Epoch 3/50
# 13/13 [==============================] - 3s 258ms/step - loss: 0.8837 - accuracy: 0.8789 - val_loss: 0.7351 - val_accuracy: 0.9148
# Epoch 4/50
# 13/13 [==============================] - 3s 255ms/step - loss: 0.4287 - accuracy: 0.9417 - val_loss: 0.4630 - val_accuracy: 0.9641
# Epoch 5/50
# 13/13 [==============================] - 3s 257ms/step - loss: 0.3062 - accuracy: 0.9513 - val_loss: 0.1198 - val_accuracy: 0.9641
# Epoch 6/50
# 13/13 [==============================] - 3s 262ms/step - loss: 0.2435 - accuracy: 0.9660 - val_loss: 0.3683 - val_accuracy: 0.9327
# Epoch 7/50
# 13/13 [==============================] - 3s 258ms/step - loss: 0.2393 - accuracy: 0.9603 - val_loss: 0.2965 - val_accuracy: 0.9641
# Epoch 8/50
# 13/13 [==============================] - 3s 261ms/step - loss: 0.1787 - accuracy: 0.9641 - val_loss: 0.3120 - val_accuracy: 0.9596
# Epoch 9/50
# 13/13 [==============================] - 3s 258ms/step - loss: 0.1216 - accuracy: 0.9718 - val_loss: 0.3041 - val_accuracy: 0.9552
# Epoch 10/50
# 13/13 [==============================] - 3s 258ms/step - loss: 0.1699 - accuracy: 0.9737 - val_loss: 0.1860 - val_accuracy: 0.9641
# Epoch 11/50
# 13/13 [==============================] - 3s 258ms/step - loss: 0.1666 - accuracy: 0.9744 - val_loss: 0.2276 - val_accuracy: 0.9641
# Epoch 12/50
# 13/13 [==============================] - 3s 256ms/step - loss: 0.1278 - accuracy: 0.9769 - val_loss: 0.1518 - val_accuracy: 0.9686
# Epoch 13/50
# 13/13 [==============================] - 3s 259ms/step - loss: 0.1784 - accuracy: 0.9731 - val_loss: 0.1595 - val_accuracy: 0.9596
# Epoch 14/50
# 13/13 [==============================] - 3s 269ms/step - loss: 0.1240 - accuracy: 0.9789 - val_loss: 0.1203 - val_accuracy: 0.9686
# Epoch 15/50
# 13/13 [==============================] - 4s 275ms/step - loss: 0.0866 - accuracy: 0.9789 - val_loss: 0.1225 - val_accuracy: 0.9731
# Epoch 16/50
# 13/13 [==============================] - 4s 280ms/step - loss: 0.0624 - accuracy: 0.9808 - val_loss: 0.1107 - val_accuracy: 0.9731
# Epoch 17/50
# 13/13 [==============================] - 4s 274ms/step - loss: 0.0670 - accuracy: 0.9846 - val_loss: 0.1290 - val_accuracy: 0.9731
# Epoch 18/50
# 13/13 [==============================] - 4s 273ms/step - loss: 0.0526 - accuracy: 0.9821 - val_loss: 0.1377 - val_accuracy: 0.9731
# Epoch 19/50
# 13/13 [==============================] - 4s 273ms/step - loss: 0.0553 - accuracy: 0.9821 - val_loss: 0.1148 - val_accuracy: 0.9731
# Epoch 20/50
# 13/13 [==============================] - 4s 276ms/step - loss: 0.0646 - accuracy: 0.9853 - val_loss: 0.1508 - val_accuracy: 0.9776
# Epoch 21/50
# 13/13 [==============================] - 4s 285ms/step - loss: 0.0503 - accuracy: 0.9898 - val_loss: 0.1123 - val_accuracy: 0.9776
# Epoch 22/50
# 13/13 [==============================] - 4s 270ms/step - loss: 0.0555 - accuracy: 0.9840 - val_loss: 0.1301 - val_accuracy: 0.9776
# Epoch 23/50
# 13/13 [==============================] - 4s 278ms/step - loss: 0.0540 - accuracy: 0.9859 - val_loss: 0.1349 - val_accuracy: 0.9776
# Epoch 24/50
# 13/13 [==============================] - 4s 282ms/step - loss: 0.0649 - accuracy: 0.9859 - val_loss: 0.1485 - val_accuracy: 0.9776
# Epoch 25/50
# 13/13 [==============================] - 4s 271ms/step - loss: 0.0551 - accuracy: 0.9865 - val_loss: 0.1173 - val_accuracy: 0.9821
# Epoch 26/50
# 13/13 [==============================] - 4s 278ms/step - loss: 0.0565 - accuracy: 0.9814 - val_loss: 0.1312 - val_accuracy: 0.9776
# Epoch 27/50
# 13/13 [==============================] - 4s 291ms/step - loss: 0.0487 - accuracy: 0.9904 - val_loss: 0.1126 - val_accuracy: 0.9731
# Epoch 28/50
# 13/13 [==============================] - 4s 289ms/step - loss: 0.0769 - accuracy: 0.9827 - val_loss: 0.2088 - val_accuracy: 0.9507
# Epoch 29/50
# 13/13 [==============================] - 4s 306ms/step - loss: 0.1339 - accuracy: 0.9667 - val_loss: 0.2041 - val_accuracy: 0.9731
# Epoch 30/50
# 13/13 [==============================] - 4s 275ms/step - loss: 0.0715 - accuracy: 0.9846 - val_loss: 0.0656 - val_accuracy: 0.9776
# Epoch 31/50
# 13/13 [==============================] - 4s 275ms/step - loss: 0.0727 - accuracy: 0.9865 - val_loss: 0.0744 - val_accuracy: 0.9821
# Epoch 32/50
# 13/13 [==============================] - 4s 273ms/step - loss: 0.0425 - accuracy: 0.9891 - val_loss: 0.0726 - val_accuracy: 0.9865
# Epoch 33/50
# 13/13 [==============================] - 4s 299ms/step - loss: 0.0416 - accuracy: 0.9904 - val_loss: 0.0656 - val_accuracy: 0.9821
# Epoch 34/50
# 13/13 [==============================] - 4s 286ms/step - loss: 0.0326 - accuracy: 0.9904 - val_loss: 0.0558 - val_accuracy: 0.9865
# Epoch 35/50
# 13/13 [==============================] - 4s 298ms/step - loss: 0.0382 - accuracy: 0.9917 - val_loss: 0.0578 - val_accuracy: 0.9821
# Epoch 36/50
# 13/13 [==============================] - 4s 288ms/step - loss: 0.0308 - accuracy: 0.9930 - val_loss: 0.0501 - val_accuracy: 0.9865
# Epoch 37/50
# 13/13 [==============================] - 4s 275ms/step - loss: 0.0252 - accuracy: 0.9910 - val_loss: 0.0547 - val_accuracy: 0.9865
# Epoch 38/50
# 13/13 [==============================] - 4s 278ms/step - loss: 0.0185 - accuracy: 0.9962 - val_loss: 0.0562 - val_accuracy: 0.9865
# Epoch 39/50
# 13/13 [==============================] - 4s 287ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0650 - val_accuracy: 0.9865
# Epoch 40/50
# 13/13 [==============================] - 4s 289ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0650 - val_accuracy: 0.9865
# Epoch 41/50
# 13/13 [==============================] - 4s 292ms/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.0640 - val_accuracy: 0.9865
# Epoch 42/50
# 13/13 [==============================] - 4s 290ms/step - loss: 0.0189 - accuracy: 0.9949 - val_loss: 0.0586 - val_accuracy: 0.9910
# Epoch 43/50
# 13/13 [==============================] - 4s 282ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0598 - val_accuracy: 0.9910
# Epoch 44/50
# 13/13 [==============================] - 4s 279ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0651 - val_accuracy: 0.9865
# Epoch 45/50
# 13/13 [==============================] - 4s 294ms/step - loss: 0.0145 - accuracy: 0.9942 - val_loss: 0.0591 - val_accuracy: 0.9865
# Epoch 46/50
# 13/13 [==============================] - 4s 283ms/step - loss: 0.0147 - accuracy: 0.9917 - val_loss: 0.0641 - val_accuracy: 0.9865
# Epoch 47/50
# 13/13 [==============================] - 4s 294ms/step - loss: 0.0231 - accuracy: 0.9923 - val_loss: 0.0625 - val_accuracy: 0.9865
# Epoch 48/50
# 13/13 [==============================] - 4s 273ms/step - loss: 0.0153 - accuracy: 0.9936 - val_loss: 0.0569 - val_accuracy: 0.9865
# Epoch 49/50
# 13/13 [==============================] - 4s 283ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0596 - val_accuracy: 0.9910
# Epoch 50/50
# 13/13 [==============================] - 4s 277ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0690 - val_accuracy: 0.9865

# %%
# plot

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = list(range(len(loss)))
figsize=(6,4)
fig, axis1 = plt.subplots(figsize=figsize)
plot1_lacc = axis1.plot(epochs, acc, 'navy', label='accuracy')
plot1_val_lacc = axis1.plot(epochs, val_acc, 'deepskyblue', label="validation accuracy")

plot1_loss = axis1.plot(epochs, loss, 'red', label='loss')
plot1_val_loss = axis1.plot(epochs, val_loss, 'lightsalmon', label="validation loss")


plots = plot1_loss + plot1_val_loss
labs = [l.get_label() for l in plots]
axis1.set_xlabel('Epoch')
axis1.set_ylabel('Loss/Accuracy')
plt.title("Loss/Accuracy History")
plt.tight_layout()
axis1.legend(loc='lower right')

# %%
score = model.evaluate(X_test, y_test, verbose=True)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0621 - accuracy: 0.9821
# accuracy: 98.21%

# %%
# predict
prob = model.predict(X_test)
pred =  (prob > 0.5).astype('int32') 

fpr, tpr, thresholds = roc_curve(y_test, prob, pos_label=1)
auc = roc_auc_score(y_test, prob)


figsize=(5,5)
fig, axis1 = plt.subplots(figsize=figsize)
x_onetoone = y_onetoone = [0, 1]
plt.plot(fpr, tpr, 'r-')
plt.plot(x_onetoone, y_onetoone, 'k--',  label="1-1")
plt.legend(loc=0)
plt.title("Receiver Operator Characteristic (ROC)")
plt.xlabel("False Positive (1 - Specificity)")
plt.ylabel("True Positive (Selectivity)")
plt.text(0.5, 0.2, "AUC ="+"{0:.2f}".format(auc), fontsize = 22, 
         bbox = dict(facecolor = 'red', alpha = 0.5))
plt.tight_layout()
# Out:
# 14/14 [==============================] - 2s 17ms/step

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, pred)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(y_test, pred)
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(y_test, pred)
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.982063
# Precision: 0.974468
# Recall: 0.991342
# F1 score: 0.982833
